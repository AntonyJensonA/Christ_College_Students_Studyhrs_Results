# %%
import pandas as pd
import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
df = pd.read_csv("House_Price_Sheet.xlsx - Sheet1.csv")
print(df)

X = df[["Area_Sq_Ft", "Bedrooms", "Total_Floors"]]
y = df["Price_Lakhs"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42
)

model = LinearRegression()
model.fit(X_train, y_train)

joblib.dump(model, "Price_Model.pkl")
print("Model saved successfully!")
# Out:
#     Area_Sq_Ft  Total_Floors  Bedrooms  Price_Lakhs
# 0          600             1         1           25
# 1          750             2         1           30
# 2          900             1         2           36
# 3         1050             3         2           42
# 4         1200             2         2           48
# 5         1350             4         3           55
# 6         1500             3         3           62
# 7         1650             5         3           68
# 8         1800             2         3           75
# 9         1950             6         4           82
# 10        2100             4         3           90
# 11        2250             7         4           98
# 12        2400             5         4          106
# 13        2550             8         4          115
# 14        2700             6         4          125
# 15        2800             9         3          132
# 16        2900             7         4          140
# 17        2950            10         4          148
# 18        3000             8         4          155
# 19        2500             4         3          110
# Model saved successfully!
